# %%
import pandas as pd
df = pd.read_csv('train.csv')
df['Age'].fillna(df['Age'].median(),inplace=True)
df['isFemale'] = 0
df.loc[df['Sex'] == 'female', 'isFemale'] = 1
from tree_engine import f
# Out:
# /var/folders/j7/5nlcf9fd527gg_vs5c9yp43r0000gn/T/ipykernel_5866/3415638542.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(),inplace=True)

# %%
f(df[['Pclass','isFemale','Age','SibSp','Parch']])
# Out:
# {'Pclass': [np.float64(1.5), np.float64(2.5)],
#  'isFemale': [np.float64(0.5)],
#  'Age': [np.float64(0.545),
#   np.float64(0.71),
#   np.float64(0.79),
#   np.float64(0.875),
#   np.float64(0.96),
#   np.float64(1.5),
#   np.float64(2.5),
#   np.float64(3.5),
#   np.float64(4.5),
#   np.float64(5.5),
#   np.float64(6.5),
#   np.float64(7.5),
#   np.float64(8.5),
#   np.float64(9.5),
#   np.float64(10.5),
#   np.float64(11.5),
#   np.float64(12.5),
#   np.float64(13.5),
#   np.float64(14.25),
#   np.float64(14.75),
#   np.float64(15.5),
#   np.float64(16.5),
#   np.float64(17.5),
#   np.float64(18.5),
#   np.float64(19.5),
#   np.float64(20.25),
#   np.float64(20.75),
#   np.float64(21.5),
#   np.float64(22.5),
#   np.float64(23.25),
#   np.float64(23.75),
#   np.float64(24.25),
#   np.float64(24.75),
#   np.float64(25.5),
#   np.float64(26.5),
#   np.float64(27.5),
#   np.float64(28.25),
#   np.float64(28.75),
#   np.float64(29.5),
#   np.float64(30.25),
#   np.float64(30.75),
# ...
